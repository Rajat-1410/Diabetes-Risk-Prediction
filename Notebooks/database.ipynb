# %%
import pandas as pd
import sqlite3

df = pd.read_excel('C:/Users/HP/Desktop/competing risk project/Diabetes_risk_prediction_project/Data/DATA_diabetes.xlsx')
conn = sqlite3.connect("../Data/diabetes_project.db")

df.to_sql(
    "Diabetes_data",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 629

# %%
cleaned_df=pd.read_excel("C:/Users/HP/Desktop/competing risk project/Diabetes_risk_prediction_project/Data/Cleaned_Diabetes.xlsx")
cleaned_df.to_sql(
    "Cleaned_data",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 1313

# %%
coded_df=pd.read_excel("C:/Users/HP/Desktop/competing risk project/Diabetes_risk_prediction_project/Data/coded_diabetes.xlsx")
coded_df.to_sql(
    "Coded_data",
    conn,
    if_exists="replace",
    index=False)
# Out:
# 1312

# %%
coded_df=pd.read_excel("C:/Users/HP/Desktop/competing risk project/Diabetes_risk_prediction_project/Data/tranformed_diabetes.xlsx")
coded_df.to_sql(
    "transformed_data",
    conn,
    if_exists="replace",
    index=False)
# Out:
# 1312
